# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\illus\Downloads\all_data_used.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      36 non-null     int64
#  1   COUNTRIES                       36 non-null     object
#  2   Healthcare_2016 ($ per capita)  36 non-null     float64
#  3   Population_2017                 36 non-null     int64
#  4   HDI_2016                        36 non-null     float64
#  5   GINI_year                       36 non-null     float64
#  6   Unemploy_2016 (%)               36 non-null     float64
#  7   Combined_2017 (%)               36 non-null     float64
#  8   ASD_2017 (%)                    36 non-null     float64
#  9   ADHD_2017 (%)                   36 non-null     float64
#  10  DEP_2017 (%)                    36 non-null     float64
#  11  SCZ_2017 (%)                    36 non-null     float64
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                        0
# COUNTRIES                         0
# Healthcare_2016 ($ per capita)    0
# Population_2017                   0
# HDI_2016                          0
# GINI_year                         0
# Unemploy_2016 (%)                 0
# Combined_2017 (%)                 0
# ASD_2017 (%)                      0
# ADHD_2017 (%)                     0
# DEP_2017 (%)                      0
# SCZ_2017 (%)                      0
# ANX_2017 (%)                      0
# ED_2017 (%)                       0
# ETOH_2017 (%)                     0
# SUICIDE_2017 (per 100.000)        0
# BD_2017 (%)                       0
# dtype: int64

# %%
hc_spend = df.groupby("Healthcare_2016 ($ per capita)")["COUNTRIES"].count()
hc_spend.sort_values(ascending =False, inplace = True)
hc_spend
# Out:
# Healthcare_2016 ($ per capita)
# 1065.875    1
# 1126.755    1
# 4024.490    1
# 4470.748    1
# 4512.845    1
# 4565.873    1
# 4666.226    1
# 4698.016    1
# 4774.269    1
# 4785.896    1
# 4844.017    1
# 5018.406    1
# 5048.876    1
# 5139.924    1
# 5550.175    1
# 5803.702    1
# 6942.187    1
# 3916.333    1
# 3833.251    1
# 3662.218    1
# 2187.367    1
# 1582.955    1
# 1897.797    1
# 1915.052    1
# 1965.018    1
# 2012.957    1
# 2057.825    1
# 2198.044    1
# 3264.368    1
# 2551.400    1
# 2627.698    1
# 2667.691    1
# 2678.230    1
# 2682.920    1
# 3105.646    1
# 9903.651    1
# Name: COUNTRIES, dtype: int64

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df1 = df.nlargest(5, "Healthcare_2016 ($ per capita)")

# %%
countries_spending = df[["COUNTRIES","Healthcare_2016 ($ per capita)"]].copy()

# %%
countries_spending.sort_values("Healthcare_2016 ($ per capita)", ascending=False, inplace=True)

# %%
countries_spending
# Out:
#    COUNTRIES  Healthcare_2016 ($ per capita)
# 29       USA                        9903.651
# 26       CHE                        6942.187
# 20       NOR                        5803.702
# 8        DEU                        5550.175
# 1        AUT                        5139.924
# 25       SWE                        5048.876
# 18       NLD                        5018.406
# 7        FRA                        4844.017
# 16       LUX                        4785.896
# 5        DNK                        4774.269
# 3        CAN                        4698.016
# 2        BEL                        4666.226
# 0        AUS                        4565.873
# 14       JPN                        4512.845
# 12       IRL                        4470.748
# 6        FIN                        4024.490
# 11       ISL                        3916.333
# 28       GBR                        3833.251
# 19       NZL                        3662.218
# 13       ITA                        3264.368
# ...

# %%
population_vs_spend = df[["Population_2017", "Healthcare_2016 ($ per capita)","COUNTRIES"]]

# %%
population_vs_spend
# Out:
#     Population_2017  Healthcare_2016 ($ per capita) COUNTRIES
# 0          24585000                        4565.873       AUS
# 1           8820000                        5139.924       AUT
# 2          11420000                        4666.226       BEL
# 3          36732000                        4698.016       CAN
# 4          10641000                        2627.698       CZE
# 5           5732000                        4774.269       DNK
# 6           5511000                        4024.490       FIN
# 7          64843000                        4844.017       FRA
# 8          82658000                        5550.175       DEU
# 9          10569000                        2198.044       GRC
# 10          9730000                        1965.018       HUN
# 11           334000                        3916.333       ISL
# 12          4753000                        4470.748       IRL
# 13         60674000                        3264.368       ITA
# ...

# %%
pop_spend = df[["Population_2017", "Healthcare_2016 ($ per capita)","COUNTRIES"]].copy()
pop_spend["total"] = pop_spend["Population_2017"] * pop_spend["Healthcare_2016 ($ per capita)"].astype(int)
pop_spend
# Out:
#     Population_2017  Healthcare_2016 ($ per capita) COUNTRIES          total
# 0          24585000                        4565.873       AUS   112230525000
# 1           8820000                        5139.924       AUT    45325980000
# 2          11420000                        4666.226       BEL    53285720000
# 3          36732000                        4698.016       CAN   172566936000
# 4          10641000                        2627.698       CZE    27953907000
# 5           5732000                        4774.269       DNK    27364568000
# 6           5511000                        4024.490       FIN    22176264000
# 7          64843000                        4844.017       FRA   314099492000
# 8          82658000                        5550.175       DEU   458751900000
# 9          10569000                        2198.044       GRC    23230662000
# 10          9730000                        1965.018       HUN    19119450000
# ...
